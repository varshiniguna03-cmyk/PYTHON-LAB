# %%
# program to find sum of 2 numbers using function
def sum(a,b):
    return a+b
x=sum(5,10)
print(x)
# Out:
# 15

# %%
def sum(a,b):
    return a-b
x=sum(7,2)
print(x)
# Out:
# 5

# %%
def sum(a,b):
    return a+b
a=int(input("enter a:"))
b=int(input("enter b:"))
print("sum",a+b)
# Out:
# enter a: 6
# enter b: 2
# sum 8
