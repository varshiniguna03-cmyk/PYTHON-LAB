# %%
#bitwise operator
a=5
b=3
print(a&b)
print(a|b)
print(a^b)
# Out:
# 1
# 7
# 6

# %%
a=int(input("enter a"))
b=int(input("enter b"))
print(a|b)
print(a&b)
print(a^b)
# Out:
# enter a 5
# enter b 3
# 7
# 1
# 6
