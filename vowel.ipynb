# %%
# character is vowel
ch = input("Enter a character: ")

if ch.lower() in ['a', 'e', 'i', 'o', 'u']:
    print("It is a vowel")
else:
    print("It is not a vowel")
# Out:
# Enter a character:  i
# It is a vowel
