# %%
# Program to stop printing at a specific number
stop = int(input("Enter the number to stop at: "))
for i in range(1, 11):
    if i == stop:
        break
    print(i)
# Out:
# Enter the number to stop at:  6
# 1
# 2
# 3
# 4
# 5
